# %%
import platform
print(platform.machine())
# Out:
# arm64

# %%
import tensorflow as tf

# %%
import numpy as np
import string

# %%
from PIL import Image
import os
from pickle import dump, load
import numpy as np
import time
import matplotlib.pyplot as pl

# %%
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical, get_file
from keras.layers import add
from keras.models import Model, load_model
from keras.layers import Input, Dense, LSTM, Embedding, Dropout

# %%
# small library for seeing the progress of loops.
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
# Loading a text file into memory
def load_doc(filename):
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

# %%
# get all imgs with their captions
def all_img_captions(filename):
    file = load_doc(filename)
    captions = file.split('\n')
    descriptions ={}
    for caption in captions[:-1]:
        img, caption = caption.split('\t')
        if img[:-2] not in descriptions:
            descriptions[img[:-2]] = [ caption ]
        else:
            descriptions[img[:-2]].append(caption)
    return descriptions

# %%
#data cleaning
def cleaning_text(captions):
    table = str.maketrans('','',string.punctuation)
    for img,caps in captions.items():
        for i,img_caption in enumerate(caps):

            img_caption.replace("-"," ")
            desc = img_caption.split()

            #converts to lowercase
            desc = [word.lower() for word in desc]
            #remove punctuation from each token
            desc = [word.translate(table) for word in desc]
            #remove hanging 's and a
            desc = [word for word in desc if(len(word)>1)]
            #remove tokens with numbers in them
            desc = [word for word in desc if(word.isalpha())]
            #convert back to string

            img_caption = ' '.join(desc)
            captions[img][i]= img_caption
    return captions

# %%
def text_vocabulary(descriptions):
    # build vocabulary of all unique words
    vocab = set()

    for key in descriptions.keys():
        [vocab.update(d.split()) for d in descriptions[key]]

    return vocab

# %%
#All descriptions in one file
def save_descriptions(descriptions, filename):
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + '\t' + desc )
    data = "\n".join(lines)
    file = open(filename,"w")
    file.write(data)
    file.close()

# %%
dataset_text = "Flickr8k_text 2"
dataset_images ="Flickr8k_Dataset"

# %%
import os

# Full file path
filename = os.path.join("Data", "Flickr8k_text 2", "Flickr8k.token.txt")

# Check if the file exists
if not os.path.exists(filename):
    print("❌ File not found at:", filename)
else:
    # Load and process the file
    descriptions = all_img_captions(filename)
    print("✅ Length of descriptions =", len(descriptions))
# Out:
# ✅ Length of descriptions = 8092

# %%
clean_descriptions = cleaning_text(descriptions)

# %%
vocabulary = text_vocabulary(clean_descriptions)
print("Length of vocabulary = ", len(vocabulary))
# Out:
# Length of vocabulary =  8763

# %%
save_descriptions(clean_descriptions, "Image-Captioning/descriptions.txt")

# %%
import time
from tensorflow.keras.utils import get_file

def download_with_retry(url, filename, max_retries=3):
    for attempt in range(max_retries):
        try:
            return get_file(filename, url)
        except Exception as e:
            if attempt == max_retries - 1:
                raise e
            print(f"Download attempt {attempt + 1} failed. Retrying in 5 seconds...")
            time.sleep(5)

# %%
weights_url = "https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
weights_path = download_with_retry(weights_url, 'xception_weights.h5')
model = Xception(include_top=False, pooling='avg', weights=weights_path)

# %%
def extract_features(directory):
    features = {}
    valid_images = ['.jpg', '.jpeg', '.png']

# %%
from tqdm import tqdm
import os
from PIL import Image
import numpy as np

def extract_features(directory, model, valid_images={".jpg", ".jpeg", ".png"}):
    features = {}

    for img in tqdm(os.listdir(directory)):
        ext = os.path.splitext(img)[1].lower()
        if ext not in valid_images:
            continue

        filename = os.path.join(directory, img)
        image = Image.open(filename)
        image = image.resize((299, 299))
        image = np.expand_dims(image, axis=0)
        image = image / 127.5
        image = image - 1.0

        feature = model.predict(image)
        features[img] = feature

    return features

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import preprocess_input

# Load pre-trained model (excluding top layers)
#base_model = InceptionV3(weights='imagenet')
#model = Model(inputs=base_model.input, outputs=base_model.layers[-2].output)

# %%
dataset_images = "Data/Flickr8k_Dataset/Flicker8k_Dataset"

# %%
import os

if not os.path.exists(dataset_images):
    raise FileNotFoundError(f"Folder does not exist: {dataset_images}")

# %%
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.preprocessing import image
import numpy as np
import os
from tqdm import tqdm

def extract_features(directory, model, valid_images={".jpg", ".jpeg", ".png"}):
    features = {}

    for img_name in tqdm(os.listdir(directory)):
        ext = os.path.splitext(img_name)[1].lower()
        if ext not in valid_images:
            continue

        img_path = os.path.join(directory, img_name)
        try:
            img = image.load_img(img_path, target_size=(299, 299))  # For Xception
            img_array = image.img_to_array(img)
            img_array = np.expand_dims(img_array, axis=0)
            img_array = preprocess_input(img_array)

            feature = model.predict(img_array, verbose=0)
            features[img_name] = feature.flatten()
        except Exception as e:
            print(f"[ERROR] Skipping {img_name}: {e}")

    return features

# %%
dataset_images = "Data/Flickr8k_Dataset/Flicker8k_Dataset"

# Extract and save
features = extract_features(dataset_images, model)
dump(features, open("Data/features.p", "wb"))

# Load later
features = load(open("Data/features.p", "rb"))
# Out:
# 100%|██████████| 8091/8091 [08:52<00:00, 15.20it/s]

# %%
def load_clean_descriptions(filepath, dataset):
    descriptions = {}
    with open(filepath, 'r') as file:
        for line in file:
            tokens = line.strip().split()
            if len(tokens) < 2:
                continue
            image_id, image_desc = tokens[0], tokens[1:]
            image_id = image_id.split('.')[0]  # Removes .jpg
            if image_id in dataset:
                if image_id not in descriptions:
                    descriptions[image_id] = []
                desc = ' '.join(image_desc)
                descriptions[image_id].append(desc)
    return descriptions

# %%
def load_photos(filename):
    file = load_doc(filename)
    photos = file.split("\n")[:-1]
    photos_present = [photo for photo in photos if os.path.exists(os.path.join(dataset_images, photo))]
    return photos_present

# %%
def load_features(photos):
    #loading all features
    all_features = load(open("features.p","rb"))
    #selecting only needed features
    features = {k:all_features[k] for k in photos}
    return features

# %%
def loading_data(filename):
    with open(filename, 'r') as file:
        text = file.read()
    # Split into lines and get only image IDs (removing extensions)
    images = text.strip().split('\n')
    image_ids = [img.split('.')[0] for img in images]
    return image_ids

# %%
import os

# 1. Use correct path (update based on actual folder name)
filename = "Data/Flickr8k_text 2/Flickr_8k.trainImages.txt"

# 2. Ensure the file exists
if not os.path.exists(filename):
    raise FileNotFoundError(f"Missing file: {filename}")

# 3. Load training image IDs
def loading_data(filename):
    with open(filename, 'r') as file:
        text = file.read()
    return [line.strip().split('.')[0] for line in text.strip().split('\n')]

train = loading_data(filename)

# 4. Load photos by IDs
def load_photos(filename):
    with open(filename, 'r') as file:
        text = file.read()
    return [line.strip().split('.')[0] for line in text.strip().split('\n')]

train_imgs = load_photos(filename)

# 5. Load cleaned descriptions
def load_clean_descriptions(filepath, dataset):
    with open(filepath, 'r') as file:
        descriptions = {}
        for line in file:
            tokens = line.strip().split()
            img_id, img_desc = tokens[0], tok

# %%
def dict_to_list(descriptions):
    all_desc = []
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

# %%
print("Train Image IDs:", train_imgs[:5])
# Out:
# Train Image IDs: ['2513260012_03d33305cf', '2903617548_d3e38d7f88', '3338291921_fe7ae0c8f8', '488416045_1c6d903fe0', '2644326817_8f45080b87']

# %%
with open("Image-Captioning/descriptions.txt", "r") as file:
    for _ in range(5):
        print(file.readline())
# Out:
# 1000268201_693b08cb0e.jpg	child in pink dress is climbing up set of stairs in an entry way
#
# 1000268201_693b08cb0e.jpg	girl going into wooden building
#
# 1000268201_693b08cb0e.jpg	little girl climbing into wooden playhouse
#
# 1000268201_693b08cb0e.jpg	little girl climbing the stairs to her playhouse
#
# 1000268201_693b08cb0e.jpg	little girl in pink dress going into wooden cabin

# %%
def load_clean_descriptions(filepath, dataset):
    descriptions = {}
    found = 0
    with open(filepath, 'r') as file:
        for line in file:
            tokens = line.strip().split()
            if len(tokens) < 2:
                continue
            image_id, image_desc = tokens[0], tokens[1:]
            image_id_clean = image_id.split('.')[0]
            if image_id_clean in dataset:
                found += 1
                if image_id_clean not in descriptions:
                    descriptions[image_id_clean] = []
                desc = ' '.join(image_desc)
                descriptions[image_id_clean].append(desc)
    print(f"Matched {found} descriptions from the dataset.")
    return descriptions

# %%
train_descriptions = load_clean_descriptions("Image-Captioning/descriptions.txt", train_imgs)
print("Sample description keys:", list(train_descriptions.keys())[:5])
# Out:
# Matched 30000 descriptions from the dataset.
# Sample description keys: ['1000268201_693b08cb0e', '1001773457_577c3a7d70', '1002674143_1b742ab4b8', '1003163366_44323f5815', '1007129816_e794419615']

# %%
train_descriptions.keys()
# Out:
# dict_keys(['1000268201_693b08cb0e', '1001773457_577c3a7d70', '1002674143_1b742ab4b8', '1003163366_44323f5815', '1007129816_e794419615', '1007320043_627395c3d8', '1009434119_febe49276a', '1012212859_01547e3f17', '1015118661_980735411b', '1015584366_dfcec3c85a', '101654506_8eb26cfb60', '101669240_b2d3e7f17b', '1016887272_03199f49c4', '1019077836_6fc9b15408', '1019604187_d087bf9a5f', '1020651753_06077ec457', '1022454428_b6b660a67b', '1022975728_75515238d8', '102351840_323e3de834', '1024138940_f1fefbdce1', '102455176_5f8ead62d5', '1026685415_0431cbf574', '1028205764_7e8df9a2ea', '1030985833_b0902ea560', '103195344_5d2dc613a3', '103205630_682ca7285b', '1032460886_4a598ed535', '104136873_5b5d41be75', '1042020065_fb3d3ba5ba', '1042590306_95dea0916c', '1048710776_bb5b0a5c7c', '1052358063_eae6744153', '105342180_4d4a40b47f', '1053804096_ad278b25f1
# %%
from tensorflow.keras.preprocessing.text import Tokenizer

def create_tokenizer(descriptions):
    lines = []
    for desc_list in descriptions.values():
        lines.extend(desc_list)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
tokenizer = create_tokenizer(train_descriptions)
print("Sample word index:", list(tokenizer.word_index.items())[:10])
vocab_size = len(tokenizer.word_index) + 1
print("Vocab size:", vocab_size)
# Out:
# Sample word index: [('in', 1), ('the', 2), ('on', 3), ('is', 4), ('and', 5), ('dog', 6), ('with', 7), ('man', 8), ('of', 9), ('two', 10)]
# Vocab size: 7577

# %%
def max_length(descriptions):
    desc_list = dict_to_list(descriptions)
    return max(len(d.split()) for d in desc_list)

max_length = max_length(train_descriptions)
print(max_length)
# Out:
# 32

# %%
train_descriptions
# Out:
# {'1000268201_693b08cb0e': ['child in pink dress is climbing up set of stairs in an entry way',
#   'girl going into wooden building',
#   'little girl climbing into wooden playhouse',
#   'little girl climbing the stairs to her playhouse',
#   'little girl in pink dress going into wooden cabin'],
#  '1001773457_577c3a7d70': ['black dog and spotted dog are fighting',
#   'black dog and tricolored dog playing with each other on the road',
#   'black dog and white dog with brown spots are staring at each other in the street',
#   'two dogs of different breeds looking at each other on the road',
#   'two dogs on pavement moving toward each other'],
#  '1002674143_1b742ab4b8': ['little girl covered in paint sits in front of painted rainbow with her hands in bowl',
#   'little girl is sitting in front of large painted rainbow',
#   'small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it',
#   'there is girl with pigtails sitting in front of rainbow painting',
#   'young girl with pigtails painting outside in the grass'],
#  '1003163366_44323f5815': ['man lays on bench while his dog sits by him',
#   'man lays on the bench to which white dog is also tied',
#   'man sleeping on bench outside with white and black dog sitting next to him',
#   'shirtless man lies on park bench with his dog',
#   'man laying on bench holding leash of dog sitting on ground'],
#  '1007129816_e794419615': ['man in an orange hat starring at something',
#   'man wears an orange hat and glasses',
#   'man with gauges and glasses is wearing blitz hat',
#   'man with glasses is wearing beer can crocheted hat',
#   'the man with pierced ears is wearing glasses and an orange hat'],
#  '1007320043_627395c3d8': ['child playing on rope net',
#   'little girl climbing on red roping',
#   'little girl in pink climbs rope bridge at the park',
#   'small child grips onto the red ropes at the playground',
#   'the small child climbs on red ropes on playground'],
#  '1009434119_febe49276a': ['black and white dog is running in grassy garden surrounded by white fence',
#   'black and white dog is running through the grass',
#   'boston terrier is running in the grass',
#   'boston terrier is running on lush green grass in front of white fence',
#   'dog runs on the green grass near wooden fence'],
#  '1012212859_01547e3f17': ['dog shakes its head near the shore red ball next to it',
#   'white dog shakes on the edge of beach with an orange ball',
#   'dog with orange ball at feet stands on shore shaking off water',
#   'white dog playing with red ball on the shore near the water',
#   'white dog with brown ears standing near water with head turned to one side'],
#  '1015118661_980735411b': ['boy smiles in front of stony wall in city',
#   'little boy is standing on the street while man in overalls is working on stone wall',
#   'young boy runs aross the street',
#   'young child is walking on stone paved street with metal pole and man behind him',
#   'smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him'],
#  '1015584366_dfcec3c85a': ['black dog leaps over log',
#   'grey dog is leaping over fallen tree',
#   'large black dog leaps fallen log',
#   'mottled black and grey dog in blue collar jumping over fallen tree',
#   'the black dog jumped the tree stump'],
#  '101654506_8eb26cfb60': ['brown and white dog is running through the snow',
#   'dog is running in the snow',
#   'dog running through snow',
#   'white and brown dog is running through snow covered field',
#   'the white and brown dog is running over the surface of the snow'],
#  '101669240_b2d3e7f17b': ['man in hat is displaying pictures next to skier in blue hat',
#   'man skis past another man displaying paintings in the snow',
#   'person wearing skis looking at framed pictures set up in the snow',
#   'skier looks at framed pictures in the snow next to trees',
#   'man on skis looking at artwork for sale in the snow'],
#  '1016887272_03199f49c4': ['collage of one person climbing cliff',
#   'group of people are rock climbing on rock climbing wall',
#   'group of people climbing rock while one man belays',
#   'seven climbers are ascending rock face whilst another man stands holding the rope',
#   'several climbers in row are climbing the rock while the man in red watches and holds the line'],
#  '1019077836_6fc9b15408': ['brown dog chases the water from sprinkler on lawn',
#   'brown dog plays with the hose',
#   'brown dog running on lawn near garden hose',
#   'dog is playing with hose',
#   'large brown dog running away from the sprinkler in the grass'],
#  '1019604187_d087bf9a5f': ['dog prepares to catch thrown object in field with nearby cars',
#   'white dog is about to catch yellow ball in its mouth',
#   'white dog is about to catch yellow dog toy',
#   'white dog is ready to catch yellow ball flying through the air',
#   'white dog running after yellow ball'],
#  '1020651753_06077ec457': ['black and white dog jumping in the air to get toy',
#   'black and white dog jumps up towards yellow toy',
#   'dog leaps to catch ball in field',
#   'white dog is trying to catch ball in midair over grassy field',
#   'the white dog is playing in green field with yellow toy'],
#  '1022454428_b6b660a67b': ['couple and an infant being held by the male sitting next to pond with near by stroller',
#   'couple sit on the grass with baby and stroller',
#   'couple with their newborn baby sitting under tree facing lake',
#   'man and woman care for an infant along the side of body of water',
#   'couple with baby sit outdoors next to their stroller'],
#  '1022975728_75515238d8': ['black dog running in the surf',
#   'black lab with tags frolicks in the water',
#   'dog splashes in the water',
#   'the black dog runs through the water',
#   'this is black dog splashing in the water'],
#  '102351840_323e3de834': ['man drilling hole in the ice',
#   'man is drilling through the frozen ice of pond',
#   'person in the snow drilling hole in the ice',
#   'person standing on frozen lake',
#   'two men are ice fishing'],
#  '1024138940_f1fefbdce1': ['two different breeds of brown and white dogs play on the beach',
#   'two dogs are making turn on soft sand beach',
#   'two dogs playing in the sand at the beach',
#   'two dogs playing together on beach',
#   'two large tan dogs play along sandy beach'],
#  '102455176_5f8ead62d5': ['man uses ice picks and crampons to scale ice',
#   'an ice climber in blue jacket and black pants is scaling frozen ice wall',
#   'an ice climber scaling frozen waterfall',
#   'person in blue and red ice climbing with two picks',
#   'climber climbing an ice wall'],
#  '1026685415_0431cbf574': ['black dog carries green toy in his mouth as he walks through the grass',
#   'black dog carrying something through the grass',
#   'black dog has blue toy in its mouth',
#   'dog in grass with blue item in his mouth',
#   'wet black dog is carrying green toy through the grass'],
#  '1028205764_7e8df9a2ea': ['man and baby are in yellow kayak on water',
#   'man and little boy in blue life jackets are rowing yellow canoe',
#   'man and child kayak through gentle waters',
#   'man and young boy ride in yellow kayak',
#   'man and child in yellow kayak'],
#  '1030985833_b0902ea560': ['black dog and brown dog are jumping up to catch red toy',
#   'black dog and brown dog play with red toy on courtyard',
#   'brown and black lab are outside and the black lab is catching toy in its mouth',
#   'black dog snaps at red and black object as brown dog lunges',
#   'the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway'],
#  '103195344_5d2dc613a3': ['man in black is sitting next to modern art structure in front of glass building',
#   'man sits and reads newspaper by sculpture outside of an office building',
#   'man sits near large statue',
#   'man sitting in front of metal sculpture in front of building',
#   'the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading'],
#  '103205630_682ca7285b': ['tent is being set up on the ice',
#   'two men are about to enter an ice fishing tent on snow covered lake',
#   'two men setting up blue ice fishing hut on an iced over lake',
#   'two men standing on an ice looking into something covered with blue tarp',
#   'two people standing outside blue tent structure on snowy surface'],
#  '1032460886_4a598ed535': ['man is standing in front of skyscraper',
#   'man stands in front of skyscraper',
#   'man stands in front of very tall building',
#   'behind the man in red shirt stands large skyscraper',
#   'there is skyscraper in the distance with man walking in front of the camera'],
#  '104136873_5b5d41be75': ['people sit on the mountainside and check out the view',
#   'three people are on hilltop overlooking green valley',
#   'three people hang out on top of big hill',
#   'three people overlook green valley',
#   'three people rest on ledge above the moutains'],
#  '1042020065_fb3d3ba5ba': ['boy in green shirt is looking down at many inflatable boats',
#   'boy in green shirt watches kayakers',
#   'boy looks over railing at the many boats and rafts below in the water',
#   'young boy overlooking crowd of inflatable boats',
#   'young boy wearing jersey looks down over ledge at many boats in the water'],
#  '1042590306_95dea0916c': ['man and woman pose for the camera while another man looks on',
#   'man is holding the hand of woman up to his mouth in front of some buildings while another man looks on',
#   'multiracial couple posing for picture',
#   'asian man and blond woman holding hands outdoors man in background watches',
#   'guy in blue shirt biting hand of girl in black striped jacket while another guy watches'],
#  '1048710776_bb5b0a5c7c': ['couple of several people sitting on ledge overlooking the beach',
#   'group of people sit on wall at the beach',
#   'group of teens sit on wall by beach',
#   'crowd of people at the beach',
#   'several young people sitting on rail above crowded beach'],
#  '1052358063_eae6744153': ['boy takes jump on his skateboard while another boy with skateboard watches',
#   'child is performing skateboard trick while another child with skateboard leans on wall',
#   'little boy skateboarder is doing trick on his board while another young skateboarder watches',
#   'young boy skateboarder jumping on platform on skateboard',
#   'two skateboarders'],
#  '105342180_4d4a40b47f': ['girl paddling down large river as seen from behind her',
#   'woman kayaking down river',
#   'woman paddles boat down river',
#   'woman with paddle',
#   'woman with paddle sits in boat on the water'],
#  '1053804096_ad278b25f1': ['girl in pigtails splashes in the shallow water',
#   'girls plays in the surf',
#   'girl with pigtails is playing in the ocean by the beach',
#   'girl with pigtails plays in the water',
#   'young girl in pigtails plays in the water'],
#  '1055623002_8195a43714': ['group of four children wearing pajamas have pillow fight',
#   'group of kids have pillowfight',
#   'group of young children playing pillow fight on bed',
#   'children having pillow fight',
#   'four children are having pillow fight'],
#  '1055753357_4fa3d8d693': ['two constructions workers sit on beam taking break',
#   'two construction workers are sitting up on the side of building',
#   'two construction workers sitting on an ibeam',
#   'two construction workers take seat on steel beam',
#   'two men take break from construction'],
#  '1056359656_662cee0814': ['little girl looking at brochure on train rides',
#   'young blond girl with magizine in her hands',
#   'young girl on train reads book about train rides',
#   'young girl sits on seat and looks at train pamphlet',
#   'child sitting down looking at train ride brochure'],
#  '1056873310_49c665eb22': ['brown dog is running after black dog on rocky shore',
#   'brown dog is running after the black dog',
#   'two dogs playing on beach',
#   'two dogs run across stones near body of water',
#   'two dogs run towards each other on rocky area with water in the background'],
#  '1057089366_ca83da0877': ['boy descends off the end of high diving board',
#   'child jumps off high diving board into the pool',
#   'kid jumps off the diving board and into the swimming pool below',
#   'little kid is jumping off high dive at the pool',
#   'the boy is jumping off high diving board into the pool'],
#  '1057210460_09c6f4c6c1': ['guy stands by window taking his overshirt off',
#   'man in tank top stands next to chrome door',
#   'man puts his shirt on near an elevator',
#   'man stands by an elevator with his head down',
#   'the man is putting on his shirt near an elevator'],
#  '1057251835_6ded4ada9c': ['lightcolored dog runs on the beach',
#   'small yellow dog runs on beach',
#   'tan dog runs on sandy beach',
#   'white dog is running down rocky beach',
#   'light brown dog running along the beach'],
#  '106514190_bae200f463': ['hiker standing high on bluff overlooking the mountains below',
#   'person on ski looks from hill over snow covered landscape',
#   'skier is overlooking snowcovered mountain',
#   'skier is overlooking the beautiful white snow covered landscape',
#   'skier pauses on mountaintop'],
#  '1067180831_a59dc64344': ['black and white dog is attempting to catch yellow and purple object in low cut yard',
#   'black and white dog jumps after yellow toy',
#   'black and white dog jumps to get the frisbee',
#   'black dog is jumping up to catch purple and green toy',
#   'dog jumps to catch toy'],
#  '1067675215_7336a694d6': ['man in blue shorts is laying in the street',
#   'man in blue shorts lays down outside in parking lot',
#   'man laying down in middle of street during heavy traffic',
#   'man lies on mat in parking lot between brown suv and yellow pickup with an open door',
#   'shirtless man is laying down in the middle of busy street'],
#  '1067790824_f3cc97239b': ['white and black dog and brown dog in sandy terrain',
#   'woolly dog chases doberman on beach',
#   'one dog is chasing another one on the beach',
#   'the two large dogs are running through sand',
#   'two large dogs chasing each other at the beach'],
#  '1072153132_53d2bb1b60': ['black and white dog catches toy in midair',
#   'dog and tennis ball',
#   'dog is jumping to catch object thrown at it',
#   'dog leaps while chasing tennis ball through grassy field',
#   'multicolor dog jumping to catch tennis ball in grassy field'],
#  '107318069_e9f2ef32de': ['crowd watching air balloons at night',
#   'group of hot air balloons lit up at night',
#   'people are watching hot air balloons in the park',
#   'people watching hot air balloons',
#   'seven large balloons are lined up at nighttime near crowd'],
#  '1075716537_62105738b4': ['child with helmet on his head rides bike',
#   'little boy rides bike down hill on miniature dirt bike',
#   'young boy in helmet rides bike on the road',
#   'the little boy rides his bicycle in race',
#   'the young boy pedals quickly at bmx race'],
#  '1075867198_27ca2e7efe': ['man in brown shirt and dark shorts plays on the beach with his two black dogs',
#   'man in shorts with two black dogs holds ball throwing toy at the beach',
#   'man playing with two black dogs on the beach',
#   'man with two dogs on beach',
#   'man at the beach with two dogs'],
#  '1075881101_d55c46bece': ['boy cleans the bubbles off his face',
#   'boy covered in suds has his face wiped clean',
#   'boy is covered in bubbles',
#   'child covered in foam is climbing on black inflatable ramp',
#   'person covered in soapy water is getting cleaned off'],
#  '1079274291_9aaf896cc1': ['little boy sticks his tongue out for the camera another boy looks on',
#   'two boys make faces',
#   'two young boys are looking at the camera one smiling the other sticking his tongue out',
#   'two young boys look up at the camera as one sticks out his tongue',
#   'two young boys making silly faces'],
#  '10815824_2997e03d76': ['blonde horse and blonde girl in black sweatshirt are staring at fire in barrel',
#   'girl and her horse stand by fire',
#   'girl holding horse lead behind fire',
#   'man and girl and two horses are near contained fire',
#   'two people and two horses watching fire'],
#  '1082252566_8c79beef93': ['bulldog sheep dog and boxer standing in yard',
#   'large brown dog is pushing small boston terrier with his face while anouther dog watches',
#   'large skinny dog stands near two smaller dogs int the dirt',
#   'there are three dogs starring at ball in the middle of them',
#   'three dogs of various sizes'],
#  '1084104085_3b06223afe': ['woman in yellow shirt and green shorts is climbing an artificial red wall whilst wearing safety harness',
#   'woman in blue shorts and white shirt is indoor rock climbing',
#   'the girl is climbing rock wall',
#   'the girl is in harness climbing rocks',
#   'woman climbing an artificial rock wall'],
#  '1087168168_70280d024a': ['boy is jumping on an inflatable ring and girl is watching him',
#   'boy jumping on water jumphouse',
#   'teenage boy is jumping on an inflatable slide',
#   'young boy jumping and young girl seating in an inflatable pool',
#   'two young kids are playing in the water on an inflated toy'],
#  '108898978_7713be88fc': ['skiiers walking up the hill through forest',
#   'two men are skiing in the snow in wooded area',
#   'two people wearing yellow jackets crosscountry skiing',
#   'two skiers are making their way through woodland',
#   'two skiers are sliding down trail in the woods'],
#  '108899015_bf36131a57': ['lone skier is making their way up mountain',
#   'skiiers at the top of snow covered hill',
#   'two hikers climbing snowy hill',
#   'two people are on snowcovered mountain',
#   'two people climbing up snowy mountain'],
#  '1089181217_ee1167f7af': ['brown dog running down paved pathway',
#   'brown dog running next to grass',
#   'dog is running down road',
#   'light brown dog runs down path happily',
#   'energetic brown dog running'],
#  '109202756_b97fcdc62c': ['woman dressed in blue jacket and blue jeans rides brown horse near frozen lake and snowcovered mountain',
#   'woman in blue jacket rides brown pony near water',
#   'woman rides horse near frozen lake in the wintertime',
#   'young blond woman sitting atop brown draft horse in the snowy mountains',
#   'woman blue jacket sits on daft horse near frozen lake'],
#  '109202801_c6381eef15': ['two draft horses pull cart through the snow',
#   'two golden brown horses pull sleigh driven by woman in blue coat',
#   'two horses are pulling woman in cart',
#   'two horses pull carriage driven by woman over snow covered ground',
#   'two horses pulling sled steered by smiling blond woman'],
#  '109260216_85b0be5378': ['person climbing down sheer rock cliff using rope',
#   'person climbs tall flat mountain while holding onto safety rope',
#   'person is climbing rock while holding onto white rope',
#   'person rappels down steep incline',
#   'person wearing red vest climbs up steep rock'],
#  '109260218_fca831f933': ['people stand inside rock dome',
#   'shaft of light in cave shows three spelunkers',
#   'spelunkers pose inside rock cavern while bathed in sunlight from the surface',
#   'three people sit in cave',
#   'three rock climbers are posing on big rocks'],
#  '1093716555_801aacef79': ['group of backpackers lay on the dry ground',
#   'group of hikers are resting on the ground in front of some mountains',
#   'people camp with the mountains in the background',
#   'several hikers rest with their gear in front of mountain',
#   'the group of hikers is resting in front of mountain'],
#  '1093737381_b313cd49ff': ['woman in blue dress stands with chalk portrait of two children playing by stream',
#   'woman standing in front of chalk drawing',
#   'woman stands next to chalk drawing in front of barnlike structure',
#   'woman stands outside near an elaborate chalk illustration',
#   'woman wearing blue dress is drawing picture of boy and girl on the sidewalk with sidewalk chalk'],
#  '1094462889_f9966dafa6': ['brown dog plays in deep pile of snow',
#   'dog looking at the camera in snow',
#   'dog runs through the snow',
#   'tan dog stand in the snow and looks up',
#   'the brown dog is out in the snow'],
#  '1095476286_87d4f8664e': ['boy jumping in fountain',
#   'boy plays in the fountains',
#   'child plays in fountain',
#   'little boy playing in the water',
#   'young boy is jumping through water being sprayed up from the ground'],
#  '1095580424_76f0aa8a3e': ['corgi runs out of tunnel',
#   'dog runs out of tunnel on course',
#   'dog running out of tunnel on obstacle course',
#   'the dog is running out of the tunnel on dog obedience course',
#   'the small brown and white dog is running out of small tunnel'],
#  '1095590286_c654f7e5a9': ['blond dog and black and white dog run in dirt field',
#   'dog chases another dog',
#   'yellow dog and black and white dog are running in the dirt',
#   'two dogs are running in field',
#   'two dogs running around'],
#  '1095980313_3c94799968': ['little girl in blue swimsuit is walking along wooden fence next to sandy beach',
#   'little girl with arms outstretched is posing at the beach',
#   'young girl walks on railing in front of the beach',
#   'little girl in blue swimsuit standing on handrail near beach',
#   'the little girl in the blue bathing suit is posing at the beach'],
#  '1096097967_ac305887b4': ['black and white dog drinking water from water spray',
#   'black and white dog is being soaked with jet of water in blue paddling pool',
#   'dog sticking its face into the shower from garden hose',
#   'small white dog gets sprayed by water',
#   'white and black dog is jumping into pool'],
#  '1096165011_cc5eb16aa6': ['boy smiles underwater',
#   'redheaded boy swimming underwater',
#   'small boy swimming underwater',
#   'smiling boy swims underwater in pool',
#   'the boys smiles underwater at the pool'],
#  '109671650_f7bbc297fa': ['boy in yellow shorts is standing on top of cliff',
#   'boy wearing blue and yellow walking on cliff edge',
#   'little boy standing high in the air on rock',
#   'young child is standing alone on some jagged rocks',
#   'child stands near edge of cliff'],
#  '109738763_90541ef30d': ['person on snowmobile in mid jump',
#   'snowmobiler flies through the air',
#   'snowmobile rider flies through the air on his or her machine in front of tall pine trees',
#   'rider jumps snowmobile high in rural area',
#   'the man is up in the air'],
#  '109738916_236dc456ac': ['people are riding around on snowmobiles',
#   'people pose with helmets and goggles on while riding snowmobiles',
#   'several people are taking break while on snowmobiling ride',
#   'three people and two snowmobiles',
#   'two helmeted men sit on yellow snowmobiles while another man stands behind watching'],
#  '109823394_83fcb735e1': ['three people drive atvs',
#   'three people on atvs in brown field turn their heads to look at the camera',
#   'three people on atv outside',
#   'three people on four wheel atv in field',
#   'three people ride their four wheelers through the field'],
#  '109823395_6fb423a90f': ['four wheeler jumping in an empty field',
#   'man on four wheeler is flying through the air',
#   'person is riding an orange atv in large empty field',
#   'man jumping with all terrain vehicle',
#   'man on an atv catching air'],
#  '109823397_e35154645f': ['man jumps gin the air while riding an atv',
#   'man on fourwheeler jumps near small building',
#   'an atv is airborne over field in front of white structure',
#   'person dressed in tan jacket jumps quad over harvested cornfield in front of small out building',
#   'man on four wheeler in the air'],
#  '1104133405_c04a00707f': ['boy carrying soccer ball',
#   'boy walks with ball tucked under his arm',
#   'boy walks with soccer ball near fence',
#   'boy wearing white tshirt walks on the grass and carries soccer ball',
#   'small boy carries soccer ball on field'],
#  '1105959054_9c3a738096': ['child painting picture',
#   'an artist paints clouds onto canvas',
#   'young girl painting picture',
#   'young girl with braids is painting with water colors on white paper on the wall',
#   'the child paints on large paper with water colors'],
#  '110595925_f3395c8bd6': ['cyclist is riding bicycle on curved road up hill',
#   'man in aerodynamic gear riding bicycle down road around sharp curve',
#   'man on mountain bike is pedaling up hill',
#   'man bicycle up road while cows graze on hill nearby',
#   'the biker is riding around curve in the road'],
#  '1107471216_4336c9b328': ['little girl is holding cine camera in front of her face',
#   'young girl is looking through an old fashioned video camera',
#   'young girl steadies her aim with camera',
#   'girl with rosy cheeks and lips holding black toy gun',
#   'there is kid with gun'],
#  '1110208841_5bb6806afe': ['black and white border collie catches frisbee in front of an audience',
#   'brown and white dog catches frisbee in it mouth in front of group of people',
#   'brown and white dug jumping up to catch frisbee while an audience watches',
#   'dog jumps to catch frisbee while many people watch',
#   'an agile dog catches frisbee while crowd of onlookers watches closely'],
#  '1112212364_0c48235fc2': ['baby is sitting on and playing with smooth rocks',
#   'baby is stacking rocks on the beach',
#   'small boy is playing with rocks',
#   'toddler sitting on pile of rocks holding rock at beach',
#   'toddler sits on pile of rocks'],
#  '111537217_082a4ba060': ['man climbing rock wall',
#   'man climbing the side of cliff',
#   'man is rock climbing',
#   'man with red shoes white shirt and grey pants climbing',
#   'the young man with the white tshirt and jeans is rappeling up the rock wall'],
#  '111537222_07e56d5a30': ['climber wearing blue helmet and headlamp is attached to rope on the rock face',
#   'man climbs rocky wall',
#   'rock climber climbs large rock',
#   'woman in purple snakeskin pants climbs rock',
#   'person with blue helmet and purple pants is rock climbing'],
#  '1115565519_d976d4b1f1': ['child playing with fountain at the beach',
#   'child plays with fountain',
#   'girl looks at fountain that sprays water',
#   'little girl playing in water on frog sculpture',
#   'the little girl is playing with toy in public fountain'],
#  '1115679311_245eff2f4b': ['black dog is jumping over log along beach',
#   'black dog runs along the beach and jumps over wood barrior',
#   'dog is running on the beach',
#   'dog jumping over small wall at beach near the water',
#   'an animal is running on the beach'],
#  '111766423_4522d36e56': ['black and white bird eating seeds out of someone hand',
#   'black and white bird standing on hand',
#   'small bird sits in person hand and eats seeds',
#   'black and white bird standing on hand of someone holding sunflower seeds',
#   'the small bird is clinging to finger of the hand holding the seeds'],
#  '1117972841_2b9261f95f': ['brown dog is running in the sand',
#   'brown dog playing in the sand',
#   'brown dog plays at the beach',
#   'dog is standing in the sand',
#   'dog running fast in the sand'],
#  '1118557877_736f339752': ['little boy stands in the surf',
#   'small child wades through the water while being guided by another person',
#   'young boy laughs while splashing in the ocean',
#   'young boy wearing colorful bathing suit splashing in the ocean',
#   'young child splashing in water'],
#  '1119418776_58e4b93eac': ['black and white dog is running through the field',
#   'black brown and white dog running through field',
#   'brown black and white dog is running through large field with its mouth open',
#   'dog running in field',
#   'dog with its mouth open running through field torwards the camera'],
#  '1119463452_69d4eecd08': ['girl in pink swimsuit in pool',
#   'girl swimming in pool',
#   'little girl in pink bathing suit swimming in pool',
#   'little girl swimming in pool',
#   'smiling little girl swimming in outdoor pool'],
#  '1121416483_c7902d0d49': ['child is standing on her head',
#   'little girl standing on her head',
#   'small child doing handstand on bed',
#   'young girl does handstand on bed with blue sheets',
#   'the girl is upside down on bed'],
#  '112178718_87270d9b4d': ['guy stands in the sand with snowboard behind him',
#   'man holds surfboard on the beach',
#   'man holds his snowboard in the sand',
#   'man with his surfboard stands in the sand',
#   'man is standing on white sand and holding snowboard'],
#  '112243673_fd68255217': ['people on atvs and dirt bikes are traveling along worn path in field surrounded by trees',
#   'three people are riding around on atv and motorcycles',
#   'three people on motorbikes follow trail through dry grass',
#   'three people on two dirtbikes and one fourwheeler are riding through brown grass',
#   'three people ride offroad bikes through field surrounded by trees'],
#  '1124448967_2221af8dc5': ['half naked man is sleeping on his chair outdoors',
#   'an older man sits back and relaxes on patio outside an adobe building where many bicycles are propped',
#   'shirtless man in white cap relaxes in deck chair close to three parked bicycles',
#   'man relaxing in folding chair on the street',
#   'topless old man wearing slippers navy blue pants and white hat while reclining in chair outside'],
#  '1129704496_4a61441f2c': ['brown and white and black and white dog hauling in floating toy from the ocean',
#   'both dogs retrieve the play toy from the water',
#   'two dogs in the ocean playing with toy',
#   'two dogs run through the water with rope in their mouths',
#   'two dogs tug at chew toy in the surf'],
#  '1130017585_1a219257ac': ['there are three young people one dark haired holding bottled drink one with head tilted back and finger in her mouth and one with spiked hair',
#   'the young people party in the streets',
#   'three girls make faces as one takes drink while they stand in busy street',
#   'three women on the street drinking and posing',
#   'three young women pose for the camera at parade'],
#  '1130401779_8c30182e3e': ['two brown dogs are creating large splashes as they run in river',
#   'two brown dogs in the water',
#   'two brown dogs running through water',
#   'two brown dogs runs through the water',
#   'two dogs splash through the water'],
#  '1131340021_83f46b150a': ['young boy runs while wearing sandals',
#   'little boy in striped shirt and brown shorts is running',
#   'the little boy in short sleeved shirt and shorts is running outside',
#   'the little boy is wearing black pinstripe shirt and walking on deck',
#   'young boy running outside on the pavement'],
#  '1131804997_177c3c0640': ['two men are sitting on the ground and going through their backpacks',
#   'two men sitting in front of railing are looking at something',
#   'two men with backpacks placed in front of them sitting in front of railing',
#   'two men with backpacks are sitting on cardboard along railing',
#   'two older men with backpacks sit at bus station'],
#  '1132772170_600610c5df': ['child leaping from bed to bed behind the back of man',
#   'man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room',
#   'man wearing yellow shirt standing in the middle of two beds that boy is jumping on in the background',
#   'young child jumping on the bed as man looks the other way',
#   'man standing in the bedroom with little boy jumping into bed'],
#  '1141718391_24164bf1b1': ['bridge through high green plants man and woman on it',
#   'man and woman are crossing over rope bridge with greenery all over them',
#   'man and woman are walking across rope bridge',
#   'man and woman crossing suspension bridge in tropical setting',
#   'woman and man walking across wooden rope bridge with caution sign beside it'],
#  '1141739219_2c47195e4c': ['family gathered at painted van',
#   'girl climbing down from the side of bright blue truck while others watch',
#   'man is helping girl step down from colorful truck whilst woman and three children watch',
#   'very colorful bus is pulled off to the side of the road as its passengers load',
#   'two women and four children standing next to brightly painted truck'],
#  '1142283988_6b227c5231': ['blond woman poses with person in pink costume',
#   'smiling woman holds person dressed in pig costume',
#   'young woman hugs young man who wearing pink costume',
#   'blond embracing young man in pink costume at event',
#   'two people are hugging and one is wearing pinkhooded stretch top'],
#  '1142847777_2a0c1c2551': ['bicyclist riding on city street',
#   'woman in blue helmet and brown shorts rides her bike on busy street',
#   'woman is riding blue bike',
#   'woman is riding her bicycle in traffic',
#   'woman wearing blue helmet rides her bicycle in parking lot'],
#  '1143373711_2e90b7b799': ['bicycle rider is crossing street',
#   'bicyclist getting ready to cross street',
#   'biker in spandex riding on busy street',
#   'man in blue and white biking gear rides down busy street',
#   'man wearing helmet riding his bicycle down the street'],
#  '1143882946_1898d2eeb9': ['lady wearing helmet holding bike',
#   'woman in blue vest and sky blue helmet stands with her bicycle in traffic',
#   'woman in helmet rides her bike behind car',
#   'woman with helmet and backpack walks next to her bike',
#   'women with bike and helmet wait for traffic'],
#  '1144288288_e5c9558b6a': ['man in shorts is jogging along street with headset',
#   'person in blue shorts and wearing walkman jogs',
#   'woman in white shirt and blue shorts is wearing headphones',
#   'woman walks on street wearing headphones',
#   'woman wearing white hat and shirt is jogging down street with plant store on the corner'],
#  '1148238960_f8cacec2fc': ['bicyclists are standing at an intersection',
#   'bicyclists waiting at an intersection',
#   'people on bicycles waiting at an intersection',
#   'people waiting at light on bikes',
#   'three bikers stop in town'],
#  '1149179852_acad4d7300': ['man without shirt on is guiding large brown horse pulling green and yellow wagon',
#   'shirtless man escorts horse pulling carriage along paved road',
#   'shirtless man leading horse that is pulling carriage',
#   'shirtless man leading small horsedrawn covered wagon down road',
#   'the shirtless man is walking the shetland pony and carriage down the street'],
#  '114949897_490ca7eaec': ['boy hits ball off of tee ball into to net',
#   'child practices hitting baseball into net while two adult men watch',
#   'man holds net while boys bats ball into it',
#   'the man is holding the net for the boy playing baseball',
#   'three people put up batting cage'],
#  '1151466868_3bc4d9580b': ['small girl spins in the waves in the bright sun',
#   'young girl plays in shallow water',
#   'young girl wears shirt and shorts as she plays in the ocean surf',
#   'girl running through the water near the shore',
#   'the little girl splashes through the water'],
#  '1153704539_542f7aa3a5': ['girl playing trumpet in marching band',
#   'teenager plays her trumpet on the field at game',
#   'young girl wearing blue shirt marching in band playing trumpet',
#   'girl playing the trumpet in marching band',
#   'girl wearing blue shirt and black shorts plays trumped outside'],
#  '1159574340_99ba8c3c59': ['child jumping into lake in wooded area while another child plays on the shore',
#   'child jumps into the water with his sneakers on',
#   'kid jumping into pool of water',
#   'little boy in sneakers jumping into water',
#   'the man takes leap into the water with his shoes on'],
#  '1160034462_16b38174fe': ['elderly man in straw hat is sitting on bench',
#   'elderly man sits alone on park bench',
#   'an old man in straw hat sits on park bench',
#   'the old man in the brown hat is sitting on the bench',
#   'white haired man in gray sweater and straw hat sitting on bench under tree'],
#  '1160441615_fe6b3c5277': ['three girls are walking across bridge covered with wood and surrounded by trees',
#   'three girls walking along an arched garden pathway',
#   'three girls walk under an arbor on path surrounded by trees',
#   'three women walking through tunnel in park',
#   'three women walk through plant covered atrium hallway'],
#  '1163282319_b729b24c46': ['girl dressed in red top red cap and light colored shorts sits on rock outside',
#   'little girl in red hat and yellow flip flops sits on rock',
#   'little girl with red hood and shirt is sitting with legs sprawled on rock her mouth open',
#   'young girl wearing yellow flipflops is sitting on large boulder',
#   'the little girl sits on top of rock'],
#  '116409198_0fe0c94f3b': ['man eats near tent in the snow',
#   'man sitting near tent in the snow and ice',
#   'mountaineer sits in the snow in front of yellow tent under clear blue sky',
#   'person wearing hooded jacket sitting on snow in front of yellow tent',
#   'young man in hooded jacket sitting on snow in mountain area'],
#  '1164765687_7aca07bbe7': ['man in red shirt and glasses is bending down towards small dog on blanket with several stuffed animals',
#   'man in red shirt is giving toys to small dog',
#   'man is playing tug of war with his dog',
#   'man playing with black dog on white blanket',
#   'man playing with his dog on the blanket on the floor'],
#  '1167662968_e466f1e80a': ['guy with nose piercing',
#   'man in red cap with nose ring',
#   'teenage boy has silver ring protruding from his nose',
#   'closeup picture of man with nose ring and brown shirt',
#   'young man with nose ring and hat'],
#  '1167908324_8caab45e15': ['man is standing by group of video games in bar',
#   'man standing in bar with neon beer sign hanging on the wall',
#   'man stands next to bank of computer gambling machines',
#   'man stands next to three video game machines and beer sign',
#   'man stands next to three video machines'],
#  '1169307342_e7a4685a5c': ['big brown dog plays with smaller grey dog on the grass',
#   'the dark brown dog is playing with the light brown dog',
#   'two brown dogs are running through the grass',
#   'two brown dogs run side by side',
#   'two dogs running and playing rough in the grass'],
#  '1176580356_9810d877bf': ['big dog catches ball on his nose',
#   'brown and black dog is jumping to catch red ball',
#   'brown and black dog jumps for red ball',
#   'dog jumps to get orange ball on his head',
#   'the brown and black dog is jumping up to catch red ball'],
#  '118187095_d422383c81': ['parents are pushing little children in red car carts',
#   'twin boys being pushed in small car shaped strollers in parade',
#   'twin toddlers dressed alike being pushed in plastic car strollers in parade',
#   'two children ride in toy cars',
#   'two kids being pushed in car shaped strollers in parade'],
#  '118309463_a532b75be9': ['boys baseball team wear their uniforms',
#   'small boy smiles as he stands with others wearing the same black hats',
#   'children sporting their florida dolphin caps',
#   'the boys are all wearing the same baseball hats',
#   'three boys wearing florida marlins hats'],
#  '1184967930_9e29ce380d': ['brown dog running through the grass and flowers',
#   'dog in field',
#   'dog running in field of grass and flowers',
#   'dog running in shrubbery along stream',
#   'dog walks through field'],
#  '1187435567_18173c148b': ['small brown and black dog',
#   'small brown and black dog playing with toy',
#   'small dog plays with toy on top of white blanket',
#   'small shaggy dog playing with toy on blanket',
#   'terrier dog playing with toy on blanket'],
#  '1187593464_ce862352c6': ['big tan dog runs on grass with big stick in his mouth',
#   'dog running across grassy field with stick in its mouth',
#   'dog running with stick in his mouth',
#   'dog runs toward the camera with stick in its mouth',
#   'the dog carrying long stick in its mouth'],
#  '1189977786_4f5aaed773': ['dog jumping into swimming pool',
#   'grey dog runs alongside pool while yellow dog jumps into the pool',
#   'one dog is jumping into pool while another runs alongside the pool edge',
#   'one tan dog jumping in pool while the other grey dog is on the deck',
#   'two dogs jumping into swimming pool'],
#  '1191338263_a4fa073154': ['little old lady sitting next to an advertisement',
#   'an asian woman waiting at an underground train stop',
#   'an old woman sits in transit station next to backlit advertisement',
#   'woman sits in subway station',
#   'woman with an umbrella is sitting at station with an aquos commercial on the wall'],
#  '1193116658_c0161c35b5': ['girl rides unicycle as another rides scooter next to her',
#   'girl rides unicycle with child who rides scooter',
#   'young girl rides unicycle next to another riding scooter on busy street',
#   'the girl on the unicycle reaches out for the child on the scooter',
#   'there is girl on unicycle and child on scooter'],
#  '119534510_d52b3781a3': ['man in brown shirt sitting on dock and reading',
#   'man is sitting next to the water reading',
#   'man reading book on the dock near post',
#   'person in brown jacket is sitting on pier by the water reading',
#   'person sitting on concrete landing next to body of water'],
#  '1197800988_7fb0ca4888': ['person sits at table behind tree',
#   'person wearing purple jacket stands behind tall tree',
#   'woman in purple jacket is eating snack at table behind the tree',
#   'woman sits at picnic table eating with luggage',
#   'people eat under green trees'],
#  '1198194316_543cc7b945': ['couple walking along on sidewalk',
#   'man and woman walk outside',
#   'man and woman standing in front of refreshment stand',
#   'man in black shirt and jeans walks beside woman in black pants and flowery shirt in front of refreshment stand with others walking nearby',
#   'woman with floral shirt and purse and man with black shirt are walking while another man walks behind them'],
#  '1204996216_71d7519d9a': ['boy lays on picnic table bench',
#   'child is laying down on wooden bench',
#   'child is on bench with arms stretched out',
#   'little boy in red shirt sitting on wooden picnic table bench',
#   'little boy lies down on picnic table bench'],
#  '1206506157_c7956accd5': ['dogs fight in grass over toy',
#   'on grass two brown dogs tussle for orange toy',
#   'two dogs are playing rough in green field of grass',
#   'two dogs play with an orange toy in tall grass',
#   'two large brown dogs are playing in the grass'],
#  '1207159468_425b902bfb': ['boy and person suspended above dome structure',
#   'boy in blue shirt is posing in front of an igloo type building with person dangling from rope above the building',
#   'boy poses for picture and in the background man is hanging by rope',
#   'boy stands near structure outside',
#   'young man wearing blue shirt with strange white building in the background'],
#  '1211015912_9f3ee3a995': ['girl in brown dress surrounded by children closes her eyes',
#   'girl in yellow dress with the sun shining on her face',
#   'girl in yellow dress is standing with her eyes closed in busy park',
#   'young girl in white dress',
#   'children at park'],
#  '1213336750_2269b51397': ['man in black jacket is taking photo of man in red jacket',
#   'man in black outfit is taking photograph of man in red jacket',
#   'man takes picture of another man in an open area just off of busy street',
#   'young man taking picture of another young man outdoors',
#   'young man takes picture of another young man in front of church'],
#  '121800200_bef08fae5f': ['group of climbers begin up sheer rock face',
#   'group of rock climbers climb rock wall in forest',
#   'many people are climbing the mountain surrounded by pretty green trees',
#   'people at distance trying to climb cliff',
#   'the flat side of large rocky mountain'],
#  '121971540_0a986ee176': ['two men cleaning the outside windows of yacht',
#   'two men climb the side of boat',
#   'two men on the side of barge',
#   'two people outside cleaning windows while on ledge of boat',
#   'two people stand on the side of large white and red boat'],
#  '1222322358_225067636e': ['boy in red and white shirt is on swing',
#   'child looking back on fast moving swing',
#   'litlle boy playing on swing',
#   'young boy in orange and white swings in playground at park',
#   'young boy plays on swing'],
#  '1225443522_1633e7121f': ['girl walking alone at night on street',
#   'woman in blue coat and blue heels walks down city sidewalk at night',
#   'woman walking down brick sidewalk',
#   'woman walks down brick sidewalk at night',
#   'woman walks down city sidewalk at night'],
#  '1227655020_b11a1bb112': ['black dog and brown dog playing in tall weeds',
#   'brown dog and black dog are standing against each other in some grass',
#   'two dogs are playing outside in field',
#   'two dogs play in tall grass',
#   'two dogs wrestle together in the long grass'],
#  '1229756013_94663527d7': ['brown dog jumping in the air on brown plain',
#   'brown dog jumping into the air to catch ball',
#   'brown dog leaping to catch ball',
#   'coppery dog leaps to catch ball',
#   'dog leaps into the air in grassy field surrounded by trees'],
#  '1231229740_8dcbf80bfb': ['child in gray clothes is sleeping on red cushion',
#   'little boy has fallen asleep on miniature sofa and pacifier in his mouth',
#   'sleeping child sucking on pacifier',
#   'toddler wearing pacifier is sleeping on red blanket with teddy bear at his side',
#   'young baby sucking binky asleep in chair'],
#  '1234293791_6566284bcd': ['girl in helmet rides horse',
#   'girl rides horse',
#   'young girl wearing helmet and riding brown horse',
#   'girl with black helmet riding brown dappled horse',
#   'the little girl is riding in brown horse'],
#  '1234817607_924893f6e1': ['korean man sells soda',
#   'man is sitting at an outside bar near many soda and beer cans',
#   'man wearing glasses with aluminum cans lined up in front of him',
#   'an elderly man is smiling while sitting in front of row of soda cans',
#   'vendor selling drinks in stall'],
#  '1235580648_7eebaed9bc': ['the hatted males pose for picture',
#   'the two men are wearing tall hats one hat is red print and the other is gold colored',
#   'two men in tall hats frown at the camera',
#   'two men wear silly stove pipe hats and wear makeup',
#   'two people wearing hats sit and look at the camera'],
#  '1235681222_819231767a': ['person in blue shirt sits behind two people sitting on wood bench',
#   'people sit on benches',
#   'people sitting on benches in public area',
#   'three people sit on wood benches set on white and orange tile',
#   'three people sit waiting in lobby'],
#  '1235685934_be89b231fb': ['man in sunglasses on an overpass',
#   'man looking at the camera with another man wearing mask',
#   'man wearing sunglasses is standing next to person who is wearing hat and breathing mask',
#   'the man is wearing white shirt and sunglasses',
#   'there are two men with sunglasses one of which is wearing hat and backpack'],
#  '1236951314_0308dc4138': ['boy in wetsuit jumps into pool with bald man',
#   'boy with goggles jumping into pool containing man',
#   'child is jumping into pool while man is watching the child',
#   'swimming person is watching child jump into pool with blue water',
#   'young boy jumps in swimming pool towards bald man in the water'],
#  '1236964638_1808784a3c': ['boy flips off diving board into pool',
#   'boy is diving off diving board into swimming pool',
#   'child is diving into pool',
#   'child jumping into swimming pool from the diving board',
#   'child flips off pool diving board man and another tumbling child at poolside'],
#  '123889082_d3751e0350': ['brown dog biting gray dogs ear',
#   'brown dog biting grey dogs ear',
#   'tan dog on grass with mouth open about to bite gray dog ear',
#   'two dogs are playing in grassy field one dog is biting the ear of the other dog',
#   'two dogs are playing together on green grass'],
#  '1240297429_c36ae0c58f': ['dog in number six jersey is running through field',
#   'dog is leaping through the grass',
#   'dog is wearing red number and running through field of green grass while being chased by bird',
#   'white and tan dog leaps through the air',
#   'the dog in vest leaps in the air and there is bird flying'],
#  '124195430_d14028660f': ['brown horse and black foal on the beach',
#   'brown horse stands near black horse that is sitting on the ground',
#   'large brown horse stands over small black colt that is kneeling on the sand',
#   'an adult horse approaching foal on sandy plain',
#   'thin brown horse standing and small black horse sitting on sand'],
#  '1244140539_da4804d828': ['black and brown dog is laying on white shaggy carpet',
#   'brown and black dog is laying on shaggy rug',
#   'small brown and black dog lying down in furry rug',
#   'small dog is sitting on white carpet',
#   'small dog shakes its head on white shag carpet'],
#  '1244306891_8e78ae1620': ['smiling girls in bathing suits sitting on the sand',
#   'group of friends smile for picture at the beach',
#   'group of young ladies in bikinis',
#   'the three girls in bathing suits are all smiles',
# ...
#   'several diferent colored dogs running through the grass',
#   'the dogs are playing with tennis ball in the yard'],
#  '2234702530_a265a4df22': ['man in black jacket and jeans stands in front of brick wall',
#   'man wearing jeans and backpack stands on the sidewalk',
#   'man with backpack stands in front of brown brick wall',
#   'man with glasses and red backpack standing in front of brick wall',
#   'the man in the black jacket is waiting'],
#  '2234910971_80e0325918': ['two people are walking in desert',
#   'two people are walking through the sand',
#   'two people one with black jacket and one with blue headscarf are walking along desertlike area',
#   'two people walking along huge desert with statue in the distance',
#   'two people walk out onto the desert sand'],
#  '2236016316_f476cbbf06': ['young girl in green shirt is running in gym',
#   'young girl in green shirt playing basketball',
#   'children run inside court',
#   'the young basketball player moves into the front court',
#   'two team players wearing green shirts running along the court'],
#  '2238166082_140f8b01b8': ['child in purple winter gear is on red sled',
#   'child is sledding on red sled',
#   'girl in purple coat on red sled coasting down snowy hill',
#   'young girl is sliding down snow slope in red sled',
#   'girl wearing purple jacket rides red snow sled'],
#  '2240539658_dea8db6e55': ['brown and black dog are fighting on snow',
#   'two dogs are playing in the white snow',
#   'two dogs playing in the snow',
#   'two dogs play in the snow',
#   'two large dogs play together in the snow'],
#  '2241768909_3d96d48417': ['guy is staring at blonde lady in blue jacket',
#   'man stands next to lady with dog hat',
#   'man walks next to the girl wearing headphones on winters day',
#   'man with glasses and woman wearing hat that looks like dog are outside in the snow',
#   'woman with panda hat and headphones is in front of man outside in the snow'],
#  '2242178517_2325b85e5f': ['little girl is shoveling snow',
#   'small child dressed all in blue for winter stands holding red snowshovel with snow covered mini van behind him',
#   'small child is shoveling snow with an orange shovel',
#   'toddler shovels snowy driveway with bright orange shovel',
#   'young child shovels snow'],
#  '224273695_0b517bd0eb': ['beautiful view of the mountains on snowy day',
#   'snowy peak',
#   'people walking up snowy mountain',
#   'the brown mountains have snow on them and there are clouds in the sky',
#   'the mountain climbers set up camp at the apex'],
#  '2242863004_3a9f82a31f': ['dog attempting to chew on red ball',
#   'dog with red ball',
#   'german shepherd is playing with red ball',
#   'german shepherd is playing with red ball',
#   'german sheppard dog bting large red ball'],
#  '2243904502_2d265fed80': ['dog running with toy in his mouth',
#   'dog with yellow toy in its mouth',
#   'yellow dog running through yard covered in leaves while holding yellow toy in his mouth',
#   'dog trotting with rubber duck in its mouth',
#   'the dog has retrieved his toy'],
#  '2244024374_54d7e88c2b': ['brown and black and brown dog are playing in the water and the black one is carrying long stick in its mouth',
#   'dog runs through the water with stick while another dog stands there',
#   'two dogs are running through wet grassy area and one is carrying long stick',
#   'two dogs fight over stick in flooded field',
#   'two dogs playing in flooded field with stick'],
#  '2244171992_a4beb04d8e': ['group of school children walking around outside in their uniforms',
#   'japanese school children are going to class',
#   'japanese school girls walk down the street',
#   'people walk along on the street',
#   'uniformed schoolgirls are walking together on the street'],
#  '2244551043_21b8cca866': ['four people are lining up to purchase tickets at the theater',
#   'four people standing outside of an outdoor ticket booth',
#   'four people wait outside in line for ticket',
#   'the man and woman at the window are turned around to the man and woman behind them',
#   'two men and two women standing at the window of ticket booth'],
#  '2244613488_4d1f9edb33': ['four bicyclists ride along dirt road between two wire fences',
#   'four cyclists on country trail are passing by an electricity pylon',
#   'the four bicyclists are riding through the desert',
#   'three bikers bike across the dry land',
#   'three cyclists ride near mountain'],
#  '2245348304_08bc5642f1': ['man in hat sits outside near some cardboard boxes',
#   'man plays his guitar on the street',
#   'man sits on box and plays guitar in the street',
#   'man sits ourdoors next to cardboard boxes and plays an instrument',
#   'an older musician perfoms on the street behind cardboard box'],
#  '2245618207_fa486ba2b7': ['child in red jumps on red object while others laugh',
#   'child touching red plastic object with crowd behind him',
#   'girl in crowd laughs and climbs on something',
#   'many children having fun outside near large buildings',
#   'there is girl in red jacket smiling with her hand on red blowup and crowd behind her'],
#  '2245914678_1f82fc3d80': ['girl with dyed red hair wearing striped clothing talking on cellphone',
#   'girl with read dreadlocks is talking on the phone',
#   'red haired girl with black and white striped shirt talking on cellphone',
#   'woman with bright red hair and striped clothing talks on phone',
#   'woman with red hair and black striped shirt talking on the phone'],
#  '2245916742_73af13c733': ['man in green holding camera stands between two of the head statues on easter island',
#   'man stands between to large sculptures on field',
#   'man stands by two face structures on easter island',
#   'person stands between two giant statues that look like faces',
#   'person stands next to the easter island statues'],
#  '2246717855_c0c08fe5d2': ['crowd of young people in winter clothing waiting for the train',
#   'several people are looking at their phones in crowded station',
#   'three japanese people wait for the train',
#   'three people in an asian transportation station are all focused on their cellphones',
#   'three people in jackets holding bags looking at their phones'],
#  '224702241_05af393148': ['blond dog walks in creek with banks filled with snow',
#   'blonde dog makes his way up an icy stream with snow piled up on the sides',
#   'tan dog walks down stream between mounds of snow',
#   'brown dog walks through river between snowbanks',
#   'the dog walks through the cold water'],
#  '224702242_a62aaa6dff': ['white dog catching soccer ball midair',
#   'white dog jumps up to catch soccer ball in landscaped grassy yard',
#   'yellow lab jumping up into the air to catch soccer ball',
#   'large white dog jumps in the air to catch black and white soccer ball',
#   'white dog leaping in the air for soccer ball'],
#  '2247138288_7355861203': ['adults in winter jackets and hats swing brooms at little yellow ball while black dog looks on',
#   'group of people and dog sweeping snow',
#   'group of people playing in the snow with brooms',
#   'group of people with brooms standing in the snow with dog in the forefront',
#   'group of people standing on snow covered ground some are holding brooms there is dog with the group'],
#  '2247192427_5e106f24a9': ['children play basketball on court',
#   'four young boys play basketball',
#   'several children are playing basketball game on basketball court',
#   'three small boys play basketball indoors',
#   'three small boys playing basketball'],
#  '224766705_b77996527f': ['caravan of green and red vehicles going up mountain',
#   'line of green and red dune buggys on gravel road near rocks and large pine trees',
#   'line of off road vehicles riding along trail',
#   'long line of offroad vehicles on mountain trail',
#   'several offroad vehicles are driving down gravel road'],
#  '2249141510_f534708374': ['boy in red is jumping in playground sand pit',
#   'boy in red jumping into sandbox',
#   'boy in red jumps backward onto the sand at playground',
#   'young boy in red leaping into sand at playground',
#   'young boy wearing bright red outfit jumping into the sand at playground'],
#  '2249264723_d08655d9f2': ['boy jumps on the bright colored pillows',
#   'little boy is jumping on couch that has yellow and blue cushion resting on it',
#   'young boy jumps on the brown couch in his gray and blue spiderman outfit',
#   'young child jumping onto couch',
#   'little boy wearing gray and blue pajamas jumping on furniture with blue and orange pillow under him'],
#  '2249865945_f432c8e5da': ['dog plays in the snow',
#   'dog wearing coat looks up from the snow',
#   'small white and grey dog in jacket standing in the snow',
#   'white dog in black coat is standing in the snow',
#   'the white dog stands in the snow wearing black jacket'],
#  '2250555512_71670078f5': ['dark haired man in his twenties drinks green liquid from plastic mug',
#   'distored image of man drinking green liquid in mug',
#   'man in an oxford shirt drinks from beer mug in an large tent',
#   'man sipping drink',
#   'single man drinking mug of green liquid'],
#  '2250870111_8402d2319d': ['person is reading magazine on snowing sidewalk',
#   'person wearing jeans and brown coat is reading and smoking on the sidewalk by road covered with dirty snow',
#   'woman reads on newspaper on snow covered street',
#   'woman smokes cigarette and looks at magazine in the middle of snowy road',
#   'woman smoking cigarette is standing next to the road during wintery day'],
#  '2251418114_2b0cd4c139': ['boy stands on rocky mountain',
#   'child on rock formation',
#   'child sitting on rock formation',
#   'little boy sitts on top of big rock',
#   'person in red jacket on top of rocks'],
#  '2251447809_2de73afcdf': ['man dressed in black walks on an icy sidewalk',
#   'man walks on the icy sidewalk',
#   'quiet sidewalk in town with view of traffic intersection',
#   'man walking toward his car on an icy sidewalk in the city',
#   'there is man dressed in black walking on sidewalk with melted snow'],
#  '2251992614_0c601fae2c': ['busy street of people and two men are wearing no shirts',
#   'man walks with his shirt off and rolled up pants in busy city street',
#   'many people are walking in crowded street',
#   'the lady watches the man without shirt',
#   'young people are walking around public square on warm day'],
#  '2252123185_487f21e336': ['bunch on people are seated in stadium',
#   'crowded stadium is full of people watching an event',
#   'crowd of people fill up packed stadium',
#   'crowd sitting in an indoor stadium',
#   'stadium full of people watch game'],
#  '2252264255_03fefc25af': ['two boys eating apples playing on cement car barrier',
#   'two boys with apples leap over barrier in the street',
#   'two little boys eating apples climing over retaining wall',
#   'two little boys holding apples near the street',
#   'two young boys with apples hop concrete barrier'],
#  '2252299132_14ca6e584b': ['boy walks',
#   'boy wearing face paint walks along red track',
#   'boy with face paint is running on track',
#   'young boy running race on track with painted face',
#   'boy with painted face is walking around track'],
#  '2252403744_148fc11f68': ['an asian girl and boy playing on with yellow ball on black and white floor',
#   'two children play and one has beach ball',
#   'two children play with ball on the floor',
#   'two young children playing with each other and ball',
#   'young girl in pink dress plays with boy and ball'],
#  '2252635585_b48b3485b0': ['two big dogs play in the snow under tree',
#   'two dogs are playing in the snow next to tree',
#   'two dogs are playing with tennis ball in snow near tree',
#   'two dogs play in the snow on the ground near tree with one on top of the other',
#   'two dogs tussle in the snow over tennis ball'],
#  '2254913901_569f568926': ['louis vuitton store window at night',
#   'woman looks at clothes in louis vuitton store window',
#   'woman widow shops outside of louis vuitton store',
#   'the woman in black is looking at outfits in clothing store window',
#   'woman on the street window shops in front of the store louis vuitton'],
#  '2255266906_8222af18b9': ['bird sits in leafless tree',
#   'bird sits in tree',
#   'black bird sits in dead tree',
#   'black bird sitting in leafless tree',
#   'grey dove in bare tree'],
#  '2255332561_3375897ff0': ['lone man climbing the side of large rock wall',
#   'man is on the side of mountain and hiking around huge rocks',
#   'man stands on the rocky ledge of large cliff',
#   'person stands atop rock face',
#   'the man is on the mountainside'],
#  '2255338013_566127590b': ['man is abseiling down cliff over the ocean',
#   'man is repelling down cliff next to lake',
#   'man is repelling down the side of mountain over the ocean',
#   'person is swinging by cord over the ocean',
#   'person rappelling cliff above body of water'],
#  '2255342813_5b2ac6d633': ['person climbing down rocky cliffside with water below',
#   'person repelling on the side of cliff face',
#   'person wearing black with white helmet is going down mountainside with water below',
#   'extreme climbing over ocean',
#   'looking down on someone climbing cliff over water'],
#  '2255685792_f70474c6db': ['three individuals are posing on skis behind no skiing sign',
#   'three people in skiing gear are standing behind no skiing sign',
#   'three people on skis are standing behind no skiing sign',
#   'three people standing in the snow behind no skiing sign',
#   'three people stand ready to ski next to no skiing sign'],
#  '2256138896_3e24b0b28d': ['man does technical rock climbing',
#   'man dressed in all black is climbing down mountain supported by cords',
#   'man is climbing the side of cliff',
#   'man wearing white helmet is abseiling down sandy colored rock face',
#   'rock climber with white helmet is repelling'],
#  '2256218522_53b92bcbb2': ['black and white dog is running through the sand at beach',
#   'black and white dog playing in the sand',
#   'dog bounding across the sandy landscape in front of people watching',
#   'dog lunges across beach',
#   'black dog running across dirt'],
#  '2256231539_05c27179f1': ['child holds football and runs from other children',
#   'young boy in blue uniform running with football while playing game of flag football',
#   'young boy weating blue shorts and cleats holding football running from other boys',
#   'young male carrying football and running while two other boys run behind him',
#   'the boy in blue runs with the ball whilst being chased by two boys in red'],
#  '2256320794_0286c31bfa': ['dog is waling on sand',
#   'dog that looks like lassie making funny face',
#   'puppy runs in the sand',
#   'dog has mouth open in field',
#   'the collie is standing outdoors on sandy area'],
#  '2257099774_37d0d3aa9a': ['an elderly asian woman wearing blue winter coat and red hat in front of food counter',
#   'woman in red cap in store',
#   'woman wearing red hat and black coat',
#   'woman with red hat and face stands in front of jars',
#   'the hapy asian woman is at the market'],
#  '2257294002_0073263c54': ['the children of family play while they wait',
#   'three asian kids dance while man looks on',
#   'three children do jumping jacks in public place while man sits and looks on',
#   'three children jumping while an older man watches from row of chairs nearby',
#   'three young children jump while an older man watches from his seat'],
#  '2257631407_1529b9db39': ['couple of playful kids in sweats and jeans romp on the grass',
#   'girl on someone back is laughing',
#   'kids playing around',
#   'someone holding little girl hanging upside down',
#   'two peoplw with top of heads on grass'],
#  '2257798999_d9d1b9a45a': ['as the brown dog looks the other way large black and white dog plays with smaller black dog',
#   'orange brown and white and brown dogs on grass',
#   'three dogs playing and laying on the grass',
#   'three dogs playing in yard together',
#   'three dogs play together'],
#  '2258662398_2797d0eca8': ['child in black wetsuit is in the waves on surfboard',
#   'kid on surfboard riding small wave',
#   'small boy in black is surfing',
#   'young boy in black wetsuit surfs in the water',
#   'young surfer rides wave'],
#  ...}

# %%
def data_generator(descriptions, features, tokenizer, max_length):
    while True:
        for key, description_list in descriptions.items():
            feature = features[key][0]
            input_image, input_sequence, output_word = create_sequences(
                tokenizer, max_length, description_list, feature
            )
            for i in range(len(input_image)):
                yield ({'input_1': input_image[i], 'input_2': input_sequence[i]}, output_word[i])

# %%
all_features = load(open("Data/features.p", "rb"))

# %%
import os
print("File exists?", os.path.exists("Data/features.p"))
# Out:
# File exists? True

# %%
from pickle import load

def load_features(photos):
    all_features = load(open("Data/features.p", "rb"))
    print(all_features)
    features = {k: all_features[k] for k in photos if k in all_features}
    return features

# %%
# Load features only for the training images
train_features = load_features(train_imgs)

# Define output signature for tf.data.Dataset
output_signature = (
    {
        'input_1': tf.TensorSpec(shape=(2048,), dtype=tf.float32),
        'input_2': tf.TensorSpec(shape=(max_length,), dtype=tf.int32)
    },
    tf.TensorSpec(shape=(vocab_size,), dtype=tf.float32)
)

# Create the generator function
gen = data_generator(train_descriptions, train_features, tokenizer, max_length)

# Build tf.data.Dataset
dataset = tf.data.Dataset.from_generator(
    gen,
    output_signature=output_signature
)

# Batch the dataset
dataset = dataset.batch(32)
# Out:
# {'2387197355_237f6f41ee.jpg': array([0.39725822, 0.3979755 , 0.4062515 , ..., 0.03228263, 0.24208975,
#        0.25930053], dtype=float32), '2609847254_0ec40c1cce.jpg': array([0.72011304, 0.89264107, 0.7368498 , ..., 0.8861274 , 0.6436659 ,
#        0.16261266], dtype=float32), '2046222127_a6f300e202.jpg': array([0.15686972, 0.18843442, 0.46955705, ..., 1.8327725 , 0.31223977,
#        1.3179474 ], dtype=float32), '2914331767_8574e7703d.jpg': array([0.50990796, 0.10232179, 0.17212133, ..., 0.0132215 , 0.02868181,
#        0.3537618 ], dtype=float32), '536495604_b22bbc905a.jpg': array([0.2675991 , 0.06973106, 0.85819465, ..., 0.7069738 , 0.48383307,
#        0.31856054], dtype=float32), '241345721_3f3724a7fc.jpg': array([0.33875665, 0.01516162, 0.167454  , ..., 0.06873137, 0.16644123,
#        0.0851322 ], dtype=float32), '3215108916_0473007b47.jpg': array([0.1035572 , 0.23053709, 0.20547661, ..., 0.01789992, 0.09880701,
#        0.81773597], dtype=float32), '479807465_cf42f39d00.jpg': array([0.13546817, 0.5281743 , 0.16790228, ..., 0.2639965 , 0.27123404,
#        0.19043776], dtype=float32), '470373679_98dceb19e7.jpg': array([0.27379698, 0.31368446, 0.2667863 , ..., 0.13183004, 0.07147222,
#        1.2588694 ], dtype=float32), '2445654384_4ee3e486e1.jpg': array([0.20372069, 0.37151438, 0.10720576, ..., 0.44014633, 1.2469174 ,
#        0.59995896], dtype=float32), '3099091086_f75f0ce09d.jpg': array([0.58211875, 0.42375842, 0.5401982 , ..., 0.8603161 , 0.33601356,
#        0.6018195 ], dtype=float32), '3263395801_5e4cee2b9e.jpg': array([0.32594067, 0.16244052, 0.14206943, ..., 0.2228162 , 1.0079949 ,
#        0.26182207], dtype=float32), '3259231890_16fe167b31.jpg': array([0.39209136, 0.6081588 , 0.596379  , ..., 0.3528912 , 0.7535274 ,
#        0.33294296], dtype=float32), '2636876892_9353521a1c.jpg': array([0.22941543, 0.32013053, 0.15399913, ..., 0.704931  , 0.01599538,
#        0.8031197 ], dtype=float32), '823675317_b5fbdb17b3.jpg': array([0.31869572, 0.78183115, 0.47476292, ..., 0.72308904, 0.21061751,
#        0.32495177], dtype=float32), '523249012_a0a25f487e.jpg': array([0.3378234 , 0.35809442, 0.49591628, ..., 1.2415045 , 0.71301436,
#        0.6298455 ], dtype=float32), '311267421_e204e643cf.jpg': array([0.8232591 , 1.0747356 , 0.39217532, ..., 0.15263271, 0.58005214,
#        0.4609725 ], dtype=float32), '416960865_048fd3f294.jpg': array([0.29636288, 0.43715394, 0.13172385, ..., 0.24689795, 1.1728767 ,
#        0.8966781 ], dtype=float32), '3721881082_afe9fc734e.jpg': array([0.4997499 , 0.24625456, 1.6251771 , ..., 0.15480165, 0.32908577,
#        0.33105767], dtype=float32), '2548777800_d7b9cf1c2b.jpg': array([0.3051384 , 0.31441855, 0.18028596, ..., 0.7789782 , 0.28083295,
#        0.34270242], dtype=float32), '2789937754_5d1fa62e95.jpg': array([0.52824795, 0.7881047 , 0.3004861 , ..., 1.3627267 , 0.75920236,
#        0.09353261], dtype=float32), '2088460083_42ee8a595a.jpg': array([2.109801  , 0.24335507, 0.40560335, ..., 0.43696737, 0.16817814,
#        0.73981637], dtype=float32), '1224851143_33bcdd299c.jpg': array([0.72334254, 0.26795834, 0.46630463, ..., 0.25534976, 0.8025315 ,
#        0.00161658], dtype=float32), '543007912_23fc735b99.jpg': array([0.27265406, 0.53114355, 1.1531835 , ..., 0.51092434, 0.38960406,
#        0.26692146], dtype=float32), '290019324_23582048d4.jpg': array([0.37996924, 0.5756426 , 0.17585628, ..., 0.3977982 , 0.12663439,
#        0.31169593], dtype=float32), '2441354291_b32e00e5a6.jpg': array([0.01620751, 0.06586623, 0.46232182, ..., 0.007149  , 0.1378991 ,
#        0.5286689 ], dtype=float32), '3655155990_b0e201dd3c.jpg': array([0.04356431, 0.06498867, 0.15921828, ..., 0.07802833, 0.2792678 ,
#        0.06820048], dtype=float32), '2968693931_52d161b8e7.jpg': array([3.8243309e-01, 5.5592436e-01, 5.2891870e-04, ..., 1.3837777e-01,
#        1.6585267e-01, 3.0583647e-01], dtype=float32), '3503544012_1771be9d3a.jpg': array([0.1560787 , 0.17442375, 0.24639462, ..., 0.18176708, 0.10734028,
#        0.33662987], dtype=float32), '3264397357_72f084cac1.jpg': array([0.08817595, 0.08973459, 0.69443583, ..., 1.4026762 , 1.0384699 ,
#        0.7434221 ], dtype=float32), '2846037553_1a1de50709.jpg': array([0.52886415, 0.2672094 , 0.03302426, ..., 0.16157043, 0.2618931 ,
#        0.3448883 ], dtype=float32), '2473737724_355599a263.jpg': array([0.23122433, 0.29813033, 0.7597429 , ..., 0.3697621 , 0.99564123,
#        0.21380904], dtype=float32), '2545363449_1985903f82.jpg': array([0.42208976, 0.48966676, 1.1445631 , ..., 1.6134946 , 0.88247275,
#        0.11736283], dtype=float32), '3720366614_dfa8fe1088.jpg': array([0.11940327, 0.35976803, 0.40656888, ..., 0.65997183, 0.3309059 ,
#        0.59685385], dtype=float32), '1858963639_4588cd4be9.jpg': array([0.46405655, 0.628068  , 0.8792456 , ..., 0.61446226, 0.42788693,
#        0.30643937], dtype=float32), '2505360288_c972bd29c4.jpg': array([0.15946728, 0.06491925, 0.8749303 , ..., 0.639892  , 0.46086437,
#        0.2337166 ], dtype=float32), '2695085632_10c4e6ea78.jpg': array([0.48300347, 0.4914832 , 0.3119935 , ..., 0.7595745 , 0.61465836,
#        0.41291183], dtype=float32), '3724718895_bd03f4a4dc.jpg': array([0.4881682 , 1.1330721 , 0.0930838 , ..., 0.31670415, 0.9379721 ,
#        0.6245074 ], dtype=float32), '2726301121_95a2fbd22b.jpg': array([0.3985493 , 0.26344025, 0.21948072, ..., 0.6055553 , 0.80207753,
#        0.23678502], dtype=float32), '2716457668_187a6d2b1c.jpg': array([0.4624844 , 0.14760292, 0.0904898 , ..., 0.18540078, 0.00591456,
#        0.03782889], dtype=float32), '2959581023_54402c8d88.jpg': array([0.44448823, 0.0906682 , 0.10642705, ..., 0.07166798, 0.07960902,
#        0.14316323], dtype=float32), '2643263887_a32ffb878f.jpg': array([0.34222254, 0.11911698, 0.21740046, ..., 0.14264336, 0.43930483,
#        0.36387685], dtype=float32), '3027397797_4f1d305ced.jpg': array([0.20995167, 0.34723175, 0.5086009 , ..., 0.29736805, 0.14770842,
#        0.11573971], dtype=float32), '241347760_d44c8d3a01.jpg': array([0.03388235, 0.10142584, 0.2647584 , ..., 0.4914132 , 0.29958004,
#        0.3372609 ], dtype=float32), '2343525685_3eba3b6686.jpg': array([0.52034944, 0.06765109, 0.37186044, ..., 0.34535018, 0.6319175 ,
#        0.6582627 ], dtype=float32), '1923476156_e20976b32d.jpg': array([0.06517974, 0.78916204, 0.34336412, ..., 0.5465152 , 0.9508716 ,
#        0.3852001 ], dtype=float32), '3700346840_bb80d622f7.jpg': array([0.4921623 , 0.21591027, 0.13253981, ..., 0.03751241, 0.55773073,
#        0.12440375], dtype=float32), '3217909454_7baa0edbb2.jpg': array([0.37035438, 0.30058447, 1.1581981 , ..., 1.1308142 , 0.40964675,
#        0.30705476], dtype=float32), '341430859_4519802e8f.jpg': array([0.3312053 , 0.11623154, 0.4001904 , ..., 0.1610691 , 0.66884935,
#        0.24064311], dtype=float32), '1688699579_2f72328c7e.jpg': array([0.18156314, 0.3052032 , 0.3119021 , ..., 0.11460712, 0.7326606 ,
#        0.2301169 ], dtype=float32), '3534668485_6887629ff0.jpg': array([1.2333976 , 0.33060956, 0.825115  , ..., 0.6457826 , 0.10619826,
#        0.13813761], dtype=float32), '2698487246_e827404cac.jpg': array([0.34011638, 0.60322225, 0.67795587, ..., 0.32944703, 0.0145954 ,
#        0.78468066], dtype=float32), '2937497894_e3664a9513.jpg': array([0.3495131 , 0.27915275, 0.28858232, ..., 0.2365194 , 0.31769925,
#        0.4595108 ], dtype=float32), '3692593096_fbaea67476.jpg': array([0.03995614, 0.10542591, 0.13727105, ..., 0.08615804, 0.34866732,
#        0.07145775], dtype=float32), '3259222690_69737f2a6e.jpg': array([0.24443576, 0.27954924, 0.4563572 , ..., 0.00137977, 0.13374758,
#        0.00542086], dtype=float32), '109671650_f7bbc297fa.jpg': array([0.18437217, 0.13044962, 0.07012683, ..., 1.094446  , 0.68300074,
#        0.3095463 ], dtype=float32), '801607443_f15956d1ce.jpg': array([0.08970354, 0.0618099 , 0.13218947, ..., 0.09679102, 0.07376304,
#        0.09428858], dtype=float32), '583087629_a09334e1fb.jpg': array([0.12350656, 0.40372813, 0.25811282, ..., 0.0505284 , 0.09492105,
#        0.12035052], dtype=float32), '478209058_21e2c37c73.jpg': array([0.20538782, 0.44373474, 0.13755438, ..., 0.29509962, 0.5838934 ,
#        0.7652943 ], dtype=float32), '3497224764_6e17544e0d.jpg': array([0.7239656 , 0.7205756 , 0.50528944, ..., 0.14670353, 0.8031651 ,
#        0.7820913 ], dtype=float32), '3216901052_269ace7b3c.jpg': array([0.30411416, 0.03487979, 1.4692796 , ..., 0.7136687 , 0.5873017 ,
#        0.10691682], dtype=float32), '697490420_67d8d2a859.jpg': array([0.20712551, 0.10861929, 0.18113975, ..., 0.65463686, 1.0843344 ,
#        0.0155951 ], dtype=float32), '150387174_24825cf871.jpg': array([0.04736439, 0.333498  , 0.04849766, ..., 0.02481867, 1.245395  ,
#        0.53602767], dtype=float32), '3436418401_b00ceb27c0.jpg': array([0.5791962 , 0.07161791, 0.7611953 , ..., 0.2535469 , 0.24687907,
#        0.00115144], dtype=float32), '2466420387_86fe77c966.jpg': array([0.35654038, 0.6525464 , 0.25487632, ..., 0.39934948, 0.63351196,
#        0.5196078 ], dtype=float32), '3622216490_1314a58b66.jpg': array([0.15406586, 0.26054883, 0.31964087, ..., 0.8522604 , 0.10184376,
#        0.10189556], dtype=float32), '514222303_cb98584536.jpg': array([0.20883256, 0.5841181 , 0.64568686, ..., 1.1020445 , 1.3954182 ,
#        0.35052434], dtype=float32), '3694093650_547259731e.jpg': array([1.3346184 , 0.6464938 , 1.1740413 , ..., 0.9221083 , 0.41847622,
#        0.2993037 ], dtype=float32), '3165936115_cb4017d94e.jpg': array([0.717656  , 0.52568096, 1.1678407 , ..., 0.06571196, 1.0384074 ,
#        0.22777084], dtype=float32), '2507312812_768b53b023.jpg': array([0.172694  , 0.21755412, 0.09082063, ..., 0.17676404, 1.6568189 ,
#        0.6862086 ], dtype=float32), '347186933_880caaf53b.jpg': array([0.6140347, 0.6162813, 0.4291469, ..., 1.0022577, 1.1248748,
#        1.0729674], dtype=float32), '3655773435_c234e94820.jpg': array([0.19639008, 0.00812093, 0.10048127, ..., 0.08975607, 0.77465755,
#        0.18728144], dtype=float32), '2864340145_d28b842faf.jpg': array([0.23670346, 0.08132865, 0.4633417 , ..., 0.16891411, 0.75240386,
#        0.00119234], dtype=float32), '303795791_98ebc1d19a.jpg': array([0.2121827 , 0.18719402, 0.2629584 , ..., 0.30030784, 0.01589441,
#        0.21460214], dtype=float32), '3286822339_5535af6b93.jpg': array([1.5632188 , 0.51252484, 1.5680742 , ..., 0.70323163, 1.1754335 ,
#        0.42180866], dtype=float32), '3502459991_fdec2da131.jpg': array([0.95686734, 0.23158804, 0.4044116 , ..., 0.6259836 , 0.5524794 ,
#        0.01172012], dtype=float32), '3272002857_ace031f564.jpg': array([0.10470543, 0.12314226, 0.1992286 , ..., 0.32637867, 0.2651996 ,
#        0.18940467], dtype=float32), '2764732789_1392e962d0.jpg': array([0.08095337, 0.3969406 , 0.1406706 , ..., 0.42391947, 0.04310554,
#        0.23800956], dtype=float32)}

# %%
def create_sequences(tokenizer, max_length, desc_list, feature):
    X1, X2, y = list(), list(), list()
    for desc in desc_list:
        seq = tokenizer.texts_to_sequences([desc])[0]
        for i in range(1, len(seq)):
            in_seq, out_seq = seq[:i], seq[i]
            in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
            # 🔥 No to_categorical here — use sparse integer directly
            X1.append(feature)
            X2.append(in_seq)
            y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# %%
len(train_descriptions)
# Out:
# 6000

# %%
train_features
# Out:
# {}

# %%
# Step 0: Ensure matching image IDs
train_descriptions = {k: v for k, v in train_descriptions.items() if k in train_features}

# Step 1: Create the generator function
gen = data_generator(train_descriptions, train_features, tokenizer, max_length)

# Step 2: Define output signature
output_signature = (
    {
        'input_1': tf.TensorSpec(shape=(2048,), dtype=tf.float32),
        'input_2': tf.TensorSpec(shape=(max_length,), dtype=tf.int32)
    },
    tf.TensorSpec(shape=(vocab_size,), dtype=tf.float32)
)

# Step 3: Convert to tf.data.Dataset
dataset = tf.data.Dataset.from_generator(
    gen,
    output_signature=output_signature
)

# Step 4: Batch
dataset = dataset.batch(32)

# %%
output_signature = (
    {
        'input_1': tf.TensorSpec(shape=(2048,), dtype=tf.float32),
        'input_2': tf.TensorSpec(shape=(max_length,), dtype=tf.int32)
    },
    tf.TensorSpec(shape=(), dtype=tf.int32)  # sparse label: just one integer
)


dataset = tf.data.Dataset.from_generator(
    gen,
    output_signature=output_signature
)


dataset = dataset.batch(32)

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, Embedding, LSTM, add
from tensorflow.keras.models import Model

def define_model(vocab_size, max_length):
    # Image feature extractor model (2048-D feature vector)
    inputs1 = Input(shape=(2048,), name='input_1')
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)

    # Text sequence model
    inputs2 = Input(shape=(max_length,), name='input_2', dtype='int32')  # ✅ Fixed dtype
    se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(256)(se2)

    # Decoder model
    decoder1 = add([fe2, se3])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax')(decoder2)

    # Full model
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')  # ✅ for integer labels
    return model

# %%
model = define_model(vocab_size, max_length)

# Save architecture
model_json = model.to_json()
with open("model.json", "w") as f:
    f.write(model_json)

# %%
 print(model.summary())
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_2             │ (None, 32)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_1             │ (None, 2048)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_8         │ (None, 32, 256)   │  1,939,712 │ input_2[0][0]     │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 2048)      │          0 │ input_1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 32, 256)   │          0 │ embedding_8[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_2         │ (None, 32)        │          0 │ input_2[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 256)       │    524,544 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 256)       │    525,312 │ dropout_11[0][0], │
# │                     │                   │            │ not_equal_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 256)       │          0 │ dense_12[0][0],   │
# │                     │                   │            │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 256)       │     65,792 │ add_26[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 7577)      │  1,947,289 │ dense_13[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,002,649 (19.08 MB)
#  Trainable params: 5,002,649 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
import netron

netron.start("model.json")
# Out:
# Serving 'model.json' at http://localhost:8081
# ('localhost', 8081)

# %%
import os
print(os.listdir())
# Out:
# ['test_graph.png', 'model.json', 'main.ipynb', '.DS_Store', 'uv.lock', 'pyproject.toml', 'models', 'test.py', 'models2', 'README.md', '.venv', '.python-version', 'Image-Captioning', 'descriptions.txt', 'Data', '.idea']

# %%
def load_doc(filename):
    with open(filename, 'r') as file:
        text = file.read()
    return text

def load_descriptions(doc):
    mapping = {}
    for line in doc.strip().split('\n'):
        tokens = line.split()
        if len(tokens) < 2:
            continue
        image_id, image_desc = tokens[0], tokens[1:]
        image_id = image_id.split('.')[0]  # remove '.jpg'
        desc = ' '.join(image_desc)
        if image_id not in mapping:
            mapping[image_id] = []
        mapping[image_id].append(desc)
    return mapping

# %%
doc = load_doc("Data/Flickr8k_text 2/Flickr8k.token.txt")
descriptions = load_descriptions(doc)
print("Descriptions loaded:", len(descriptions))  # should be ~8000
  # should be ~8000
# Out:
# Descriptions loaded: 8092

# %%
def clean_descriptions(descriptions):
    import string
    table = str.maketrans('', '', string.punctuation)
    for key, desc_list in descriptions.items():
        for i in range(len(desc_list)):
            desc = desc_list[i]
            desc = desc.lower()
            desc = desc.translate(table)
            desc = ' '.join([word for word in desc.split() if len(word) > 1 and word.isalpha()])
            desc_list[i] = desc

clean_descriptions(descriptions)

# %%
def save_descriptions(descriptions, filename):
    lines = []
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(f"{key}\t{desc}")
    with open(filename, 'w') as file:
        file.write('\n'.join(lines))

save_descriptions(descriptions, 'descriptions.txt')

# %%
train_features = features
train_descriptions = descriptions

# %%
print('Dataset: ', len(train_imgs))
print('Descriptions: train=', len(train_descriptions))
print('Photos: train=', len(train_features))
print('Vocabulary Size:', vocab_size)
print('Description Length: ', max_length)
# Out:
# Dataset:  6000
# Descriptions: train= 8092
# Photos: train= 8091
# Vocabulary Size: 7577
# Description Length:  32

# %%
# Define the model
model = define_model(vocab_size, max_length)
epochs = 10
batch_size = 32

# Dynamically compute steps per epoch based on training descriptions
def get_steps_per_epoch(descriptions, batch_size=32):
    total_sequences = sum(
        len(caption.split()) - 1
        for captions in descriptions.values()
        for caption in captions
    )
    # Ensure minimum one step to avoid division errors
    return max(1, total_sequences // batch_size)

# Compute steps
steps = get_steps_per_epoch(train_descriptions, batch_size)

# %%
try:
    model.fit(dataset, epochs=4, steps_per_epoch=steps, verbose=1)
except ValueError as e:
    print("ValueError:", e)
# Out:
# Epoch 1/4

# %%
import os

os.makedirs("models", exist_ok=True)

for i in range(epochs):
    dataset = data_generator(train_descriptions, train_features, tokenizer, max_length)
    model.fit(dataset, epochs=4, steps_per_epoch=steps, verbose=1)
    model.save("models/model_" + str(i) + ".h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 7
#       5 for i in range(epochs):
#       6     dataset = data_generator(train_descriptions, train_features, tokenizer, max_length)
# ----> 7     model.fit(dataset, epochs=4, steps_per_epoch=steps, verbose=1)
#       8     model.save("models/model_" + str(i) + ".h5")
#
# File ~/Desktop/Image captioning/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Desktop/Image captioning/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/__init__.py:125, in get_data_adapter(x, y, sample_weight, batch_size, steps_per_epoch, shuffle, class_weight)
#     117     return GeneratorDataAdapter(x)
#     118     # TODO: should we warn or not?
#     119     # warnings.warn(
#     120     #     "`shuffle=True` was passed, but will be ignored since the "
#    (...)
#     123     # )
#     124 else:
# --> 125     raise ValueError(f"Unrecognized data type: x={x} (of type {type(x)})")
#
# ValueError: Unrecognized data type: x=<function data_generator.<locals>.generator at 0x3150140d0> (of type <class 'function'>)
